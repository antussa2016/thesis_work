# %% [markdown]
# <a href="https://colab.research.google.com/github/antussa2016/thesis_work/blob/master/data_analysis/FLD_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/antussa2016/thesis_work
# Out:
# Cloning into 'thesis_work'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 196 (delta 25), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (196/196), 976.03 KiB | 11.09 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/thesis_work/dataset/final_data_for_modeling .csv')

# %%
df.head(1)
# Out:
#   twitter_id  stackoverflow_id  question_count  answer_count  reputation  \
# 0       10F1            145587              13           500       74297
#
#                                           answer_tag  \
# 0  ['go', 'json', 'http', 'goroutine', 'struct', ...
#
#                                         question_tag  Openness  \
# 0  ['go', 'javascript', 'python', 'c++', 'linux',...  0.839299
#
#    Conscientiousness  Extraversion  Agreeableness  Neuroticism  \
# 0           0.170988      0.083984       0.047367     0.612101
#
#   preferred_tags1 preferred_tags2 preferred_tags3  oop  web-pro  database  \
# 0               0            json               0    0        1         0
#
#    mobile
# 0       0

# %%
columns_to_drop = ['stackoverflow_id','question_count','answer_count','reputation','answer_tag','question_tag','preferred_tags1', 'preferred_tags2','preferred_tags3']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df.head(1)
# Out:
#   twitter_id  Openness  Conscientiousness  Extraversion  Agreeableness  \
# 0       10F1  0.839299           0.170988      0.083984       0.047367
#
#    Neuroticism  oop  web-pro  database  mobile
# 0     0.612101    0        1         0       0

# %%
df_melted = df.melt(id_vars=['twitter_id','Openness', 'Conscientiousness','Extraversion','Agreeableness','Neuroticism'],
                    value_vars=['oop','web-pro','database','mobile'],
                    var_name='Class_Label',
                    value_name='Value')

# %%
df_filtered = df_melted[df_melted['Value'] != 0]

# %%
df_filtered.drop(columns=['Value'], inplace=True)
# Out:
# <ipython-input-13-fb52c6a5f0df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['Value'], inplace=True)

# %%
df_filtered.sort_values(by='twitter_id', inplace=True)
# Out:
# <ipython-input-14-917e29191118>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by='twitter_id', inplace=True)

# %%
df_filtered.reset_index(drop=True, inplace=True)

# %%
new_df = df_filtered.reset_index(drop=True).copy()

# %%
# print(df_filtered)

# %%
new_df.head(30)
# Out:
#          twitter_id  Openness  Conscientiousness  Extraversion  Agreeableness  \
# 0              10F1  0.839299           0.170988      0.083984       0.047367
# 1              1tgr  0.849555           0.100009      0.032557       0.001654
# 2    @GabMarioPower  0.784907           0.373114      0.065501       0.007660
# 3   @GeorgFritzsche  0.830270           0.610333      0.094850       0.041251
# 4   @GeorgFritzsche  0.830270           0.610333      0.094850       0.041251
# 5         @JoelKatz  0.924783           0.089528      0.138598       0.011523
# 6        @JorisMeys  0.502466           0.231200      0.321757       0.253410
# 7    @RoutSiddharth  0.654301           0.603105      0.056930       0.024484
# 8        @agriffini  0.894954           0.124989      0.083294       0.009011
# 9        @agriffini  0.894954           0.124989      0.083294       0.009011
# 10   @balarajagopal  0.689216           0.625448      0.197740       0.037679
# 11         @borland  0.881779           0.042616      0.072976       0.003885
# 12         @borland  0.881779           0.042616      0.072976       0.003885
# 13     @dave_newton  0.908483           0.036053      0.051867       0.020315
# 14     @dave_newton  0.908483           0.036053      0.051867       0.020315
# 15           @dirvo  0.889837           0.542461      0.111912       0.018609
# 16   @frozenfractal  0.943385           0.144389      0.029940       0.000488
# 17   @joshua_ulrich  0.923367           0.150006      0.125104       0.030985
# 18         @jreback  0.878768           0.649009      0.022765       0.044978
# 19       @loufranco  0.906012           0.412525      0.166902       0.025388
# 20       @loufranco  0.906012           0.412525      0.166902       0.025388
# 21        @micke314  0.866666           0.202756      0.241201       0.012424
# 22     @oscar_lopez  0.728216           0.417443      0.310452       0.049950
# 23    @r_keith_hill  0.836233           0.463201      0.027805       0.006766
# 24      @samsaffron  0.872176           0.152406      0.116154       0.008163
# 25    @scottenderle  0.991006           0.224005      0.152189       0.055775
# 26  @shafikyaghmour  0.956738           0.360674      0.120429       0.055310
# 27           @shog9  0.969204           0.113049      0.141419       0.016013
# 28     @tarynpivots  0.733824           0.277062      0.086460       0.116735
# 29         @ucfagls  0.918899           0.425124      0.151750       0.056372
#
#     Neuroticism Class_Label
# 0      0.612101     web-pro
# 1      0.392036         oop
# 2      0.313509      mobile
# 3      0.296325      mobile
# 4      0.296325         oop
# 5      0.161807         oop
# 6      0.897157         oop
# 7      0.304385         oop
# 8      0.288220     web-pro
# 9      0.288220         oop
# 10     0.223963         oop
# 11     0.432516         oop
# 12     0.432516     web-pro
# 13     0.535220         oop
# 14     0.535220     web-pro
# 15     0.359172         oop
# 16     0.290291         oop
# 17     0.290947         oop
# 18     0.308163         oop
# 19     0.216581         oop
# 20     0.216581      mobile
# 21     0.333723    database
# 22     0.684055         oop
# 23     0.456381         oop
# 24     0.482848         oop
# 25     0.365120         oop
# 26     0.138727         oop
# 27     0.355974     web-pro
# 28     0.443780    database
# 29     0.293626         oop

# %%
new_df.drop('twitter_id', axis=1, inplace=True)

# %%
new_df
# Out:
#       Openness  Conscientiousness  Extraversion  Agreeableness  Neuroticism  \
# 0     0.839299           0.170988      0.083984       0.047367     0.612101
# 1     0.849555           0.100009      0.032557       0.001654     0.392036
# 2     0.784907           0.373114      0.065501       0.007660     0.313509
# 3     0.830270           0.610333      0.094850       0.041251     0.296325
# 4     0.830270           0.610333      0.094850       0.041251     0.296325
# ...        ...                ...           ...            ...          ...
# 1101  0.902336           0.361918      0.143275       0.002886     0.333019
# 1102  0.828491           0.308223      0.169396       0.026558     0.444964
# 1103  0.919490           0.425579      0.162430       0.064284     0.416771
# 1104  0.919490           0.425579      0.162430       0.064284     0.416771
# 1105  0.972275           0.116447      0.139582       0.006947     0.321106
#
#      Class_Label
# 0        web-pro
# 1            oop
# 2         mobile
# 3         mobile
# 4            oop
# ...          ...
# 1101     web-pro
# 1102         oop
# 1103         oop
# 1104      mobile
# 1105     web-pro
#
# [1106 rows x 6 columns]

# %%
# new_df.to_csv('FLD_data.csv', index=False)
