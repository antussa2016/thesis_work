# %% [markdown]
# <a href="https://colab.research.google.com/github/antussa2016/thesis_work/blob/master/data_analysis/FLD_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/antussa2016/thesis_work
# Out:
# Cloning into 'thesis_work'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 177 (delta 11), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (177/177), 966.70 KiB | 2.71 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('thesis_work/dataset/output.csv')

# %%
df.head(1)
# Out:
#   twitter_id  stackoverflow_id  question_count  answer_count  reputation  \
# 0       10F1            145587              13           500       74297
#
#                                           answer_tag  \
# 0  ['go', 'json', 'http', 'goroutine', 'struct', ...
#
#                                         question_tag  Openness  \
# 0  ['go', 'javascript', 'python', 'c++', 'linux',...  0.839299
#
#    Conscientiousness  Extraversion  ...  preferred_tags1  preferred_tags2  \
# 0           0.170988      0.083984  ...               go             json
#
#   preferred_tags3 micro-oop oop  web-pro  database  mobile  statistic  other
# 0              os         0   0        1         0       0          1      1
#
# [1 rows x 22 columns]

# %%
columns_to_drop = ['stackoverflow_id','question_count','answer_count','reputation','answer_tag','question_tag','preferred_tags1', 'preferred_tags2','preferred_tags3']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df.head(1)
# Out:
#   twitter_id  Openness  Conscientiousness  Extraversion  Agreeableness  \
# 0       10F1  0.839299           0.170988      0.083984       0.047367
#
#    Neuroticism  micro-oop  oop  web-pro  database  mobile  statistic  other
# 0     0.612101          0    0        1         0       0          1      1

# %%
df_melted = df.melt(id_vars=['twitter_id','Openness', 'Conscientiousness','Extraversion','Agreeableness','Neuroticism'],
                    value_vars=['micro-oop','oop','web-pro','database','mobile','statistic','other'],
                    var_name='Class_Label',
                    value_name='Value')

# %%
df_filtered = df_melted[df_melted['Value'] != 0]

# %%
df_filtered.drop(columns=['Value'], inplace=True)
# Out:
# <ipython-input-35-fb52c6a5f0df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['Value'], inplace=True)

# %%
df_filtered.sort_values(by='twitter_id', inplace=True)
# Out:
# <ipython-input-36-917e29191118>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by='twitter_id', inplace=True)

# %%
df_filtered.reset_index(drop=True, inplace=True)

# %%
new_df = df_filtered.reset_index(drop=True).copy()

# %%
# print(df_filtered)

# %%
new_df.head(30)
# Out:
#          twitter_id  Openness  Conscientiousness  Extraversion  Agreeableness  \
# 0              10F1  0.839299           0.170988      0.083984       0.047367
# 1              10F1  0.839299           0.170988      0.083984       0.047367
# 2              10F1  0.839299           0.170988      0.083984       0.047367
# 3              1tgr  0.849555           0.100009      0.032557       0.001654
# 4    @GabMarioPower  0.784907           0.373114      0.065501       0.007660
# 5   @GeorgFritzsche  0.830270           0.610333      0.094850       0.041251
# 6   @GeorgFritzsche  0.830270           0.610333      0.094850       0.041251
# 7         @JoelKatz  0.924783           0.089528      0.138598       0.011523
# 8        @JorisMeys  0.502466           0.231200      0.321757       0.253410
# 9        @JorisMeys  0.502466           0.231200      0.321757       0.253410
# 10   @RoutSiddharth  0.654301           0.603105      0.056930       0.024484
# ...

# %%
new_df.drop('twitter_id', axis=1, inplace=True)

# %%
new_df
# Out:
#       Openness  Conscientiousness  Extraversion  Agreeableness  Neuroticism  \
# 0     0.839299           0.170988      0.083984       0.047367     0.612101
# 1     0.839299           0.170988      0.083984       0.047367     0.612101
# 2     0.839299           0.170988      0.083984       0.047367     0.612101
# 3     0.849555           0.100009      0.032557       0.001654     0.392036
# 4     0.784907           0.373114      0.065501       0.007660     0.313509
# ...        ...                ...           ...            ...          ...
# 1289  0.902336           0.361918      0.143275       0.002886     0.333019
# 1290  0.828491           0.308223      0.169396       0.026558     0.444964
# 1291  0.919490           0.425579      0.162430       0.064284     0.416771
# 1292  0.919490           0.425579      0.162430       0.064284     0.416771
# 1293  0.972275           0.116447      0.139582       0.006947     0.321106
#
#      Class_Label
# 0        web-pro
# 1          other
# ...

# %%
# new_df.to_csv('FLD_data.csv', index=False)
